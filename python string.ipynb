# %%
#String format method to print age

# %%
age = 12
a="my age is {}"
print(a.format(age))
# Out:
# my age is 12

# %%
#string count method

# %%
a1 = "I love apples, apples are my fav. fruit"
x = a1.count("apples")
print(x)
# Out:
# 2

# %%
b = "khadak singh ke khadak ne se khadak ti hai khidkiya khidkio ke khadak ne se khadak ta hai khadak singh"
y = b.count("khadak")
print(y)
# Out:
# 6

# %%
#string find method

# %%
txt = "Hello, welcome to my world."
x = txt.find("welcome")
print(x)
# Out:
# 7

# %%
a2 = "khadak singh ke khadak ne se khadak ti hai khidkiya khidkio ke khadak ne se khadak ta hai khadak singh"
x2 = b.find("khidkiya")
print(x)
# Out:
# 2

# %%
#string partition method

# %%
txt = "Hello, welcome to my world."
a3 = "I could eat bananas all day"
x3 = txt.partition("bananas")
print(x3)
# Out:
# ('Hello, welcome to my world.', '', '')

# %%
#string split method

# %%
a = "welcome to python language"
x = a.split()
print(x)
# Out:
# ['welcome', 'to', 'python', 'language']

# %%
#string replace method

# %%
a= "I could eat bananas all day"
x=a.replace("bananas","apples")
print(x)
# Out:
# I could eat apples all day

# %%
#string alpha numeric check

# %%
a= "google25"
x=a.isalnum()
print(x)
# Out:
# True

# %%
#string join method

# %%
a=("gaurav","rishabh","himanshu","yash")
x="#".join(a)
print(x)
# Out:
# gaurav#rishabh#himanshu#yash

# %%
a=("gaurav","rishabh","himanshu","yash")
x=",".join(a)
print(x)
# Out:
# gaurav,rishabh,himanshu,yash

# %%
a=("gaurav and rishabh are friends")
x= a.index("friends")
print(x)
# Out:
# 23
