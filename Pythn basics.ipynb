# %%
5+10
# Out:
# 15

# %%
a=5
b=10
c=a+b
print(c)
# Out:
# 15

# %%
x=5
y="john"
print(x)
print(y)
# Out:
# 5
# john

# %%
a=5
b="john"
print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'str'>

# %%
x=10.4
print(type(x))
# Out:
# <class 'float'>

# %%
l1=[1,2,3,4,5]
l2=["Yash","Gaurav","Himashu"]
l3=[1,"Yash",2,"Gaurav",3,"Himanshu"]
print(l1)
print(type(l1))
print(l2)
print(type(l2))
print(l3)
print(type(l3))
# Out:
# [1, 2, 3, 4, 5]
# <class 'list'>
# ['Yash', 'Gaurav', 'Himashu']
# <class 'list'>
# [1, 'Yash', 2, 'Gaurav', 3, 'Himanshu']
# <class 'list'>

# %%
print("Hello,world")
# Out:
# Hello,world

# %%
x=(1,2,3,4,5)
x
type(x)
# Out:
# tuple

# %%
x
# Out:
# (1, 2, 3, 4, 5)

# %%
s1={1,2,3,4,5}
print(s1)
print(type(s1))
# Out:
# {1, 2, 3, 4, 5}
# <class 'set'>

# %%
x=1to5
print(x)
print(type(x))
# Out:
#   Cell In[6], line 1
#     x=1to5
#       ^
# SyntaxError: invalid decimal literal

# %%
x=1 to 5
Print(x)
# Out:
#   Cell In[7], line 1
#     x=1 to 5
#         ^
# SyntaxError: invalid syntax

# %%
x=3+5j
print(x)
print(type(x))
# Out:
# (3+5j)
# <class 'complex'>

# %%
 x={a:5}
print(x)
print(type(x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 x={a:5}
#       2 print(x)
#       3 print(type(x))
#
# NameError: name 'a' is not defined

# %%
a="raj"
x={a:5}
print(x)
# Out:
# {'raj': 5}

# %%
print(type(x))
# Out:
# <class 'dict'>

# %%
a=2
b=3
a**b
# Out:
# 8

# %%
c=2**3
c
# Out:
# 8

# %%
a=11
b=5
c=11%5
c
# Out:
# 1

# %%
a=11
b=5
a%b
# Out:
# 1

# %%
a=11
b=5
a//b
# Out:
# 2

# %%
a=15
b=7
a%b
# Out:
# 1

# %%
a//b
# Out:
# 2

# %%
a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 3
#       1 a=10
#       2 a+=5
# ----> 3 print(a)
#
# TypeError: 'int' object is not callable
