# %%
print("Hello")
# Out:
# Hello

# %%
a=2
a=a+3
print(a)
# Out:
# 5

# %%
a=10
a+=5
print(a)
# Out:
# 15

# %%
a=10
a-=7
a
# Out:
# 3

# %%
a=10
a-=15
a
# Out:
# -5

# %%
a=10
a*=11
a
# Out:
# 110

# %%
a=10
a/=7
a
# Out:
# 1.4285714285714286

# %%
x=[1,2,3]
print(1 in x)
# Out:
# True

# %%
print(5 not in x)
# Out:
# True

# %%
print(2 not in x)
# Out:
# False

# %%
print(5 in x)
# Out:
# False

# %%
x=10
y=10
print(x is y)
# Out:
# True

# %%
print(y is not x)
# Out:
# False

# %%
a=5
b=6
a<<b
# Out:
# 320

# %%
a=10
b=20
c=b+a
c
# Out:
# 30

# %%
a=10
b=20
c=b-a
c
# Out:
# 10

# %%
a=10
b=20
c=b*a
c
# Out:
# 200

# %%
a=10
b=20
c=b/a
c
# Out:
# 2.0

# %%
a=5
b=6

d=8
print("hello world")
# Out:
# hello world

# %%
a=5
b=6

print(c)
# Out:
# 11

# %%
a=[1,2,3]
square=pow(a[0],3)
print(square)
# Out:
# 1

# %%
a=[1,2,3]
sq1=pow(a[0],3)
sq2=pow(a[1],3)
sq3=pow(a[2],3)
print(sq1)
print(sq2)
print(sq3)
# Out:
# 1
# 8
# 27

# %%
#list creation

# %%
l1=[1,2,3,4,5]
print(l1)
# Out:
# [1, 2, 3, 4, 5]

# %%
course=["python","SQL","Stats"]
print(course)
# Out:
# ['python', 'SQL', 'Stats']

# %%
l1=[1,2,3,4,5]
print(l1)
print(type(l1))
print(len(l1))
# Out:
# [1, 2, 3, 4, 5]
# <class 'list'>
# 5

# %%
#list with different data types

# %%
l2=["A",2,"B",3,4,5]
print(l2)
print(type(l2))
print(len(l2))
# Out:
# ['A', 2, 'B', 3, 4, 5]
# <class 'list'>
# 6

# %%
#change item value

# %%
l2=[1,2,3,4,5,6,7,8,9]
l2[4]=10
l2[3]="A"
print(l2)
# Out:
# [1, 2, 3, 'A', 10, 6, 7, 8, 9]

# %%
#accessing values

# %%
l2=[1,2,3,4,5,6,7,8,9]
print(l2[5])
# Out:
# 6

# %%
print(l2[-6])
# Out:
# 4

# %%
l2=[1,2,3,4,5,6,7,8,9]
print(l2[3],l2[4],l2[5])
# Out:
# 4 5 6

# %%
l2=[1,2,3,4,5,6,7,8,9]
l2[5:9]
# Out:
# [6, 7, 8, 9]

# %%
l2[-6:-3]
# Out:
# [4, 5, 6]

# %%
l2[-6:]
# Out:
# [4, 5, 6, 7, 8, 9]

# %%
l2[:4]
# Out:
# [1, 2, 3, 4]

# %%
l3=["A","B","C","D","E","F"]
print(l3)
print(type(l3))
print(len(l3))
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F']
# <class 'list'>
# 6

# %%
l3[3]=4
print(l3)
# Out:
# ['A', 'B', 'C', 4, 'E', 'F']

# %%
print(l3[2])
# Out:
# C

# %%
print(l3[1:4])
# Out:
# ['B', 'C', 4]

# %%
l3[:5]
# Out:
# ['A', 'B', 'C', 4, 'E']

# %%
l3[4:]
# Out:
# ['E', 'F']

# %%
l3=["A","B","C","D","E","F"]
l3[-6:-4]
# Out:
# ['A', 'B']

# %%
# Creating a list
fruits = ["apple", "banana", "cherry"]
# Changing the second item (index 1)
fruits[1] = "blueberry"
print(fruits)  # Output: ['apple', 'blueberry', 'cherry']
# Out:
# ['apple', 'blueberry', 'cherry']

# %%
#Addition of list
#append items

# %%
course=["python","SQL","Stats"]
print(course)
# Out:
# ['python', 'SQL', 'Stats']

# %%
course=["python","SQL","Stats"]
course.append("Excel")
print(course)
# Out:
# ['python', 'SQL', 'Stats', 'Excel']

# %%
#insert item

# %%
course=["python","SQL","Stats"]
course.insert(2,"Algo")
print(course)
# Out:
# ['python', 'SQL', 'Algo', 'Stats']

# %%
#extend item

# %%
company=["TCS","Infosys","Microsoft"]
print(company)
# Out:
# ['TCS', 'Infosys', 'Microsoft']

# %%
course=["python","SQL","Stats"]
company=["TCS","Infosys","Microsoft"]
course.extend(company)
print(course)
# Out:
# ['python', 'SQL', 'Stats', 'TCS', 'Infosys', 'Microsoft']

# %%
#remove item

# %%
course=["python","SQL","Stats"]
course.remove("python")
print(course)
# Out:
# ['SQL', 'Stats']

# %%
#remove item
#pop method

# %%
course=["python","SQL","Stats"]
course.pop(1)
print(course)
# Out:
# ['python', 'Stats']

# %%
#delete method

# %%
course=["python","SQL","Stats"]
del course[2]
print(course)
# Out:
# ['python', 'SQL']

# %%
#delete whole list

# %%
l1=[1,2,3,4]
del l1

# %%
#clear list

# %%
course=["python","SQL","Stats"]
course.clear()
print(course)
# Out:
# []

# %%
#copy list method

# %%
movie=["ABC","RRR","Lagan"]
print(movie)
# Out:
# ['ABC', 'RRR', 'Lagan']

# %%
movie=["ABC","RRR","Lagan"]
Film=movie.copy()
print(Film)
# Out:
# ['ABC', 'RRR', 'Lagan']

# %%
#list method to copy

# %%
movie=["ABC","RRR","Lagan"]
Film2=list(movie)
print(Film2)
# Out:
# ['ABC', 'RRR', 'Lagan']

# %%
l3=[1,2,3]
l4=["smily","pricy","seeky"]
l5=l3+l4
print(l5)
# Out:
# [1, 2, 3, 'smily', 'pricy', 'seeky']

# %%
#max and min value

# %%
print(max(l3))
print(min(l3))
# Out:
# 3
# 1

# %%
print(max(l4))
print(min(l4))
# Out:
# smily
# pricy

# %%
#sort method

# %%
l1=[21,45,6,82,67]
l1.sort()
print(l1)
# Out:
# [6, 21, 45, 67, 82]

# %%
l1.sort(reverse=True)
print(l1)
# Out:
# [82, 67, 45, 21, 6]

# %%
#joining list

# %%
l1=[1,2,3,4,5,6]
l2=["rishabh","yash","gaurav"]
l3=l1+l2
print(l3)
# Out:
# [1, 2, 3, 4, 5, 6, 'rishabh', 'yash', 'gaurav']

# %%
l1=[1,2,3,4,5,6]
l2=["rishabh","yash","gaurav"]
l1.extend(l2)
print(l1)
# Out:
# [1, 2, 3, 4, 5, 6, 'rishabh', 'yash', 'gaurav']

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
newlist = [x for x in fruits if "a" in x]
print(newlist)
# Out:
# ['apple', 'banana', 'mango']
